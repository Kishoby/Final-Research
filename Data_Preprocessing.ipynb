# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishoby/Final-Research/blob/Data-Preprocessing/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path="/content/drive/MyDrive/Research/16 months.csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch     last_updated  temperature_celsius  \
# 0          1715849100  5/16/2024 13:15                 26.6
# 1          1715849100  5/16/2024 10:45                 19.0
# 2          1715849100   5/16/2024 9:45                 23.0
# 3          1715849100  5/16/2024 10:45                  6.3
# 4          1715849100   5/16/2024 9:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100554 entries, 0 to 100553
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       100554 non-null  object
#  1   location_name                 100554 non-null  object
#  2   latitude                      100554 non-null  float64
#  3   longitude                     100554 non-null  float64
#  4   timezone                      100554 non-null  object
#  5   last_updated_epoch            100554 non-null  int64
#  6   last_updated                  100554 non-null  object
#  7   temperature_celsius           100554 non-null  float64
#  8   temperature_fahrenheit        100554 non-null  float64
#  9   condition_text                100554 non-null  object
#  10  wind_mph                      100554 non-null  float64
#  11  wind_kph                      100554 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# ...

# %% [markdown]
# #  No Missing Values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %% [markdown]
# # No duplicate values found
